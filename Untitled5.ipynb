# %%
import csv
import numpy as np
import pandas as pd
a = 1
a
# Out:
# 1

# %%
c = pd.read_csv("Real state.csv" )

c
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
d = c[(c['price'] >=10000 )]
e = d.sort_values('city')
e
# Out:
#                    street      city    zip state  beds  baths  sq__ft  \
# 466      5308 MARBURY WAY  ANTELOPE  95843    CA     3      2    1830
# 811         4509 WINJE DR  ANTELOPE  95843    CA     3      2    2960
# 792    7921 DOE TRAIL WAY  ANTELOPE  95843    CA     5      3    3134
# 769      4636 TEAL BAY CT  ANTELOPE  95843    CA     4      2    2160
# 736         4240 WINJE DR  ANTELOPE  95843    CA     4      2    2504
# ..                    ...       ...    ...   ...   ...    ...     ...
# 135    11215 SHARRMONT CT    WILTON  95693    CA     3      2    2110
# 864  9401 BARREL RACER CT    WILTON  95693    CA     4      3    4400
# 327    9741 SADDLEBRED CT    WILTON  95693    CA     0      0       0
# 547         9360 MAGOS RD    WILTON  95693    CA     5      2    3741
# 552      12901 FURLONG DR    WILTON  95693    CA     5      3    3788
#
#             type                     sale_date   price   latitude   longitude
# ...
