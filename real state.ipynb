# %%
import numpy as np
import csv
import pandas as pd
pwd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0e4632d138ec> in <module>
#       2 import csv
#       3 import pandas as pd
# ----> 4 pwd
#
# NameError: name 'pwd' is not defined

# %%
cd \
# Out:
# C:\

# %%
cd Temp/Folder/rakesh/
# Out:
# C:\Temp\Folder\rakesh

# %%
df = pd.read_csv("real state.csv")
df
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
df.dtypes
# Out:
# street        object
# city          object
# zip            int64
# state         object
# beds           int64
# baths          int64
# sq__ft         int64
# type          object
# sale_date     object
# price          int64
# latitude     float64
# longitude    float64
# dtype: object

# %%
print(a.shape)
print(a.index)
print(a.columns)
df.sort_values('price')
# Out:
# (985, 12)
# RangeIndex(start=0, stop=985, step=1)
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')
#                       street             city    zip state  beds  baths  \
# 865     3720 VISTA DE MADERA          LINCOLN  95648    CA     3      3
# 866           14151 INDIO DR      SLOUGHHOUSE  95683    CA     3      4
# 580                  59 E ST          LINCOLN  95648    CA     3      2
# 584               386 1ST ST          LINCOLN  95648    CA     0      0
# 585               374 1ST ST          LINCOLN  95648    CA     0      0
# ..                       ...              ...    ...   ...   ...    ...
# 553  6222 CALLE MONTALVO CIR      GRANITE BAY  95746    CA     5      3
# 157             315 JUMEL CT  EL DORADO HILLS  95762    CA     6      5
# 334         3935 EL MONTE DR           LOOMIS  95650    CA     4      4
# ...

# %%
df.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
df['city']
# Out:
# 0           SACRAMENTO
# 1           SACRAMENTO
# 2           SACRAMENTO
# 3           SACRAMENTO
# 4           SACRAMENTO
#             ...
# 980         SACRAMENTO
# 981         SACRAMENTO
# 982     CITRUS HEIGHTS
# 983          ELK GROVE
# 984    EL DORADO HILLS
# Name: city, Length: 985, dtype: object

# %%
#a = df['city']

b = df.loc[(df['city'] == 'GALT')]
c = b[(b['sq__ft'] > 800 )]
c
# Out:
#                   street  city    zip state  beds  baths  sq__ft         type  \
# 55    1122 WILD POPPY CT  GALT  95632    CA     3      2    1406  Residential
# 61      306 CAMELLIA WAY  GALT  95632    CA     3      2    1130  Residential
# 63            404 6TH ST  GALT  95632    CA     3      1    1479  Residential
# 174   1121 CREEKSIDE WAY  GALT  95632    CA     3      1    1080  Residential
# 189      840 TRANQUIL LN  GALT  95632    CA     3      2    1266  Residential
# 281        993 MANTON CT  GALT  95632    CA     4      3    2307  Residential
# 296    796 BUTTERCUP CIR  GALT  95632    CA     4      2    2159  Residential
# 307      1092 MAUGHAM CT  GALT  95632    CA     5      4    3746  Residential
# 372         201 CARLO CT  GALT  95632    CA     3      2    1080  Residential
# 402  746 MOOSE CREEK WAY  GALT  95632    CA     3      2    1100  Residential
# 409        332 PALIN AVE  GALT  95632    CA     3      2    1204  Residential
# ...

# %%
d = df.loc[(df['state'] == 'CA')]
e = d[(d['type'] == 'villa')]
f = e.sort_values('price')
g= f.iloc[[0, ]]

#g.reset_index(drop=True)
g[['city','street','price']]




#c = b[(b['sq__ft'] > 800 )]
# Out:
#          city           street  price
# 0  SACRAMENTO  5840 WALERGA RD  40000

# %%
h = df[(df['sq__ft'] > 1450)]
g = h[(h.price > 59999) & (h.price < 120001) & (g.beds >2) & (g.baths > 1)]
#i = g[(g.beds >2) & (g.baths > 1)]
g.head()
# Out:
#            street        city    zip state  beds  baths  sq__ft          type  \
# 366  7342 GIGI PL  SACRAMENTO  95828    CA     4      4    1995  Multi-Family
#
#                         sale_date   price   latitude   longitude
# 366  Mon May 19 00:00:00 EDT 2008  120000  38.490704 -121.410176

# %%
j = df[(df.beds > 1) & (df.type == 'Residential')]
k = j[['city','baths','sq__ft','price','type','beds' ]]
l= k.rename(columns={"sq__ft": "Sq_feet ", "price": "Price",'type':'flat_type', 'beds':'Beds'})
l
# Out:
#                 city  baths  Sq_feet    Price    flat_type  Beds
# 0         SACRAMENTO      1       836   59222  Residential     2
# 1         SACRAMENTO      1      1167   68212  Residential     3
# 2         SACRAMENTO      1       796   68880  Residential     2
# 3         SACRAMENTO      1       852   69307  Residential     2
# 4         SACRAMENTO      1       797   81900  Residential     2
# ..               ...    ...       ...     ...          ...   ...
# 980       SACRAMENTO      3      2280  232425  Residential     4
# 981       SACRAMENTO      2      1477  234000  Residential     3
# 982   CITRUS HEIGHTS      2      1216  235000  Residential     3
# 983        ELK GROVE      2      1685  235301  Residential     4
# 984  EL DORADO HILLS      2      1362  235738  Residential     3
#
# [817 rows x 6 columns]

# %%
df.type.unique()
# Out:
# array(['Residential', 'villa', 'Multi-Family', 'Unkown'], dtype=object)
