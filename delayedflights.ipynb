# %%
pwd
# Out:
# 'C:\\Users\\rvadluri'

# %%
cd /
# Out:
# C:\

# %%
cd temp
# Out:
# C:\temp

# %%
cd Folder\rakesh
# Out:
# C:\temp\Folder\rakesh

# %%
cd "Data science"
# Out:
# C:\temp\Folder\rakesh\Data science

# %%
ls
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is 10B6-F00E
#
#  Directory of C:\temp\Folder\rakesh\Data science
#
# 02/07/2020  04:27 AM    <DIR>          .
# 02/07/2020  04:27 AM    <DIR>          ..
# 01/19/2020  10:21 AM       111,312,271 1.08012020_Data - Science  Demo.mp4
# 02/04/2020  03:58 PM             1,442 1.DelayedFlights_UC.txt
# 01/28/2020  11:30 AM         3,474,522 10.28012020_TUESDAY.docx
# 01/28/2020  11:32 AM        72,617,816 10.TUESDAY.mp4
# 01/29/2020  07:57 AM        94,016,267 11.29012020.mp4
# 01/29/2020  07:57 AM         1,063,290 11.29012020_WEDNESDAY.docx
# 01/30/2020  10:47 PM       114,428,582 12.30012020.mp4
# 01/30/2020  10:47 PM         2,006,854 12.30012020_THURSDAY.docx
# 01/30/2020  10:47 PM        98,102,210 13.31012020.mp4
# 01/30/2020  10:47 PM           924,215 13.31012020_FRIDAY.docx
# 02/01/2020  10:17 AM        87,885,408 14.01022020.mp4
# 02/01/2020  10:07 AM         3,492,769 14.01022020_SATURDAY.docx
# ...

# %%
cd Cs
# Out:
# C:\temp\Folder\rakesh\Data science\Cs

# %%
ls
# Out:
#  Volume in drive C is OSDisk
#  Volume Serial Number is 10B6-F00E
#
#  Directory of C:\temp\Folder\rakesh\Data science\Cs
#
# 02/07/2020  12:29 AM    <DIR>          .
# 02/07/2020  12:29 AM    <DIR>          ..
# 02/06/2020  10:14 PM           149,176 5433fa18-9f43-44cc-b228-74672efcd116.pdf
# 02/06/2020  10:08 PM           728,738 9fb0cc3f-19fb-4be8-8d3f-68f10a95cc16.pdf
# 02/06/2020  10:15 PM           217,418 basis.pdf
# 02/06/2020  10:17 PM           190,372 dataw.pdf
# 02/07/2020  12:29 AM       247,963,212 DelayedFlights.csv
# 02/06/2020  10:14 PM           562,029 ds_cs.pdf
# 02/06/2020  10:10 PM           692,452 graph_cs.pdf
# 02/06/2020  10:10 PM           138,489 import_files_CS.pdf
# 02/06/2020  10:12 PM           230,092 matlib.pdf
# 02/06/2020  10:16 PM           139,989 network_cs.pdf
# 02/06/2020  10:13 PM           665,028 ny_cs.pdf
# 02/06/2020  10:12 PM           190,372 pd_cs.pdf
# 02/06/2020  10:13 PM           148,619 scipy.pdf
# ...

# %%
import numpy as np
import csv
import pandas as pd

df = pd.read_csv("DelayedFlights.csv")
df
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime',
#        'CRSDepTime', 'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum',
#        'TailNum', 'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
a= df[['Cancelled','CancellationCode' ]]
a.drop_duplicates()
#df.rows
#df.loc[df['']]
# Out:
#          Cancelled CancellationCode
# 0                0                N
# 1542406          1                A
# 1546593          1                B
# 1547161          1                C

# %%
c= df.loc[(df['Cancelled'] == 1) & (df['CancellationCode'] == 'B')]
c
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 1546593     5484245  2008     10          25          6   1323.0        1255
# 1547178     5486924  2008     10          22          3   1733.0        1715
# 1548271     5491819  2008     10          15          3   1943.0        1745
# 1548430     5492348  2008     10          15          3   1610.0        1600
# 1551498     5509424  2008     10          10          5   1502.0        1450
# ...             ...   ...    ...         ...        ...      ...         ...
# 1929993     6986789  2008     12          10          3   2008.0        1805
# 1930321     6987425  2008     12          10          3   1952.0        1900
# 1930326     6987434  2008     12          10          3   1842.0        1759
# 1933981     6999301  2008     12           5          5   2253.0        2240
# 1936470     7008584  2008     12          12          5    703.0         630
#
# ...

# %%
d = c['Month'].value_counts()
d
# Out:
# 12    250
# 11     40
# 10     17
# Name: Month, dtype: int64

# %%
d.idxmax()
# Out:
# 12

# %%
e = df['Dest'].value_counts()
e
# Out:
# ORD    108984
# ATL    106898
# DFW     70657
# DEN     63003
# LAX     59969
#         ...
# INL         9
# PIR         3
# OGD         1
# CYS         1
# TUP         1
# Name: Dest, Length: 304, dtype: int64

# %%
e.head()
# Out:
# ORD    108984
# ATL    106898
# DFW     70657
# DEN     63003
# LAX     59969
# Name: Dest, dtype: int64

# %%
f = df.loc[df['Diverted']==1 ]
#f.columns
h = f[['Origin', 'Dest','Diverted']]
h
# Out:
#         Origin Dest  Diverted
# 1280       SAN  SMF         1
# 1372       SFO  SAN         1
# 1776       BOI  RNO         1
# 1831       BUR  SMF         1
# 2244       LAS  RNO         1
# ...        ...  ...       ...
# 1934369    JFK  SFO         1
# 1934921    ATL  ORD         1
# 1935596    JAN  ATL         1
# 1935716    LAX  JFK         1
# 1935978    IAD  ATL         1
#
# [7754 rows x 3 columns]

# %%
i = h['Dest'].value_counts()
i.head(10)
# Out:
# ORD    646
# DFW    461
# LGA    389
# EWR    348
# ATL    332
# MDW    313
# IAH    264
# JFK    258
# LAS    241
# PHL    173
# Name: Dest, dtype: int64

# %%
i = h['Origin'].value_counts()
i.head(10)
# Out:
# ORD    442
# ATL    367
# DFW    329
# DEN    255
# IAH    228
# JFK    219
# LAX    210
# PHX    206
# MCO    178
# DTW    173
# Name: Origin, dtype: int64
