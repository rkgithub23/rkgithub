# %%
pwd
# Out:
# 'C:\\Users\\rvadluri'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

a = np.arange(1,6,1)
b = np.arange(10,100,20)
print(a)
b
# Out:
# [1 2 3 4 5]
# array([10, 30, 50, 70, 90])

# %%
plt.plot(a,b,'r-')
plt.show()

# %%
plt.axis([0,6,0,100])
plt.plot(a,b,'bo')
plt.show()

# %%
plt.axis([0,6,0,24])
plt.plot(a,a,'yo',a,a*2,a,a*3,'g^')
plt.show()

# %%
plt.axis([0,6,0,24])
plt.plot(a,a,'yo',a,a*2,a,a*3,'g^')
plt.xlabel('rakesh')
plt.ylabel('sandhya')
plt.show()

# %%
plt.axis([0,6,0,24])
plt.plot(a,a,'yo',a,a*2,a,a*3,'g^')
plt.show()
line.set_antialiased(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-4256aec7f024> in <module>
#       2 plt.plot(a,a,'yo',a,a*2,a,a*3,'g^')
#       3 plt.show()
# ----> 4 line.set_antialiased(False)
#
# NameError: name 'line' is not defined
